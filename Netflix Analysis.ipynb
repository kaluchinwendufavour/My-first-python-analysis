# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\cw_11\OneDrive\Desktop\NetflixDataset.csv")
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0    14-Aug-20  TV-MA  4 Seasons
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4     1-Jan-20  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
data.tail
# Out:
# <bound method NDFrame.tail of      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
#number of rows and columns
data.shape
# Out:
# (7789, 11)

# %%
rows, columns = data.shape
print("there are {} rows and {} columns in the dataset" .format(rows, columns))
# Out:
# there are 7789 rows and 11 columns in the dataset

# %%
#number of cells or data in the dataset
data.size
# Out:
# 85679

# %%
#to get the names of all the columns in the dataset
data.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
#to know the data types of each columns in the dataset
data.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
#to know the all the time informations on the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# ## Data Cleaning

# %%
#First: find duplicated data in the dataset
data.duplicated().sum()
# Out:
# np.int64(2)

# %%
#to remove parmanently
data.drop_duplicates( inplace=True)

# %%
#showing the null vales of the dataset
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
#showing the nullvalues using heatmap
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
#to explore a particular column
data[data["Country"] == "Nigeria"]
# Out:
#      Show_Id Category                                   Title  \
# 15       s16    Movie                                   1-Oct
# 43       s44    Movie                                 Òlòtūré
# 116     s117    Movie                            4th Republic
# 144     s145    Movie                                 93 Days
# 243     s244    Movie                       A Trip to Jamaica
# ...      ...      ...                                     ...
# 6994   s6993    Movie                       The Wedding Party
# 6995   s6994    Movie  The Wedding Party 2: Destination Dubai
# 7370   s7369    Movie                                Up North
# 7584   s7583    Movie                       When Love Happens
# 7650   s7649    Movie                         Wives on Strike
#
#               Director                                               Cast  \
# 15      Kunle Afolayan  Sadiq Daba, David Bailie, Kayode Olaiya, Kehin...
# ...

# %%
#for House of Cards, what is the show_id and who is the director of the show
data[data.Title.isin(["House of Cards"])]
data[data.Title == "House of Cards"]
data[data.Title.str.contains("House of Cards")]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#      Release_Date Rating   Duration                     Type  \
# 2832     2-Nov-18  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
#creating a new column with the properdatatype, so it can be easy to work with
data['Date']= pd.to_datetime(data.Release_Date) 
data
# Out:
# C:\Users\cw_11\AppData\Local\Temp\ipykernel_24468\1718425705.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Date']= pd.to_datetime(data.Release_Date)
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# ...

# %%
#in which year was the highest number of tv shows and movies released
#using the dt.year method to simply get the exact year
data.Date.dt.year.value_counts()
# Out:
# Date
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
#using bar chart to visualize the above report
data.Date.dt.year.value_counts().plot(kind="bar")
plt.show()

# %%
#how many tv shows and movie 
data.groupby("Category").Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
#visualizing tv shows and movies using bar chart
data.groupby("Category").Category.count().plot(kind ='bar')
plt.show()

# %%
#to create a column for year alone 
data['year'] =data['Date'].dt.year
data
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
#showing all the movies that were released in 2019
data[(data['Category']== 'Movie') &(data['year']== 2019)]
# Out:
#      Show_Id Category                     Title  \
# 7         s8    Movie                       187
# 8         s9    Movie                       706
# 13       s14    Movie                     2,215
# 15       s16    Movie                     1-Oct
# 18       s19    Movie                    15-Aug
# ...      ...      ...                       ...
# 7771   s7770    Movie  Zindagi Na Milegi Dobara
# 7775   s7774    Movie            Zoé: Panoramas
# 7776   s7775    Movie                    Zodiac
# 7780   s7779    Movie                Zombieland
# 7785   s7784    Movie                    Zubaan
#
#                                    Director  \
# 7                            Kevin Reynolds
# 8                             Shravan Kumar
# 13                      Nottapon Boonprakob
# 15                           Kunle Afolayan
# 18                       Swapnaneel Jayakar
# ...                                     ...
# 7771                            Zoya Akhtar
# ...

# %%
# Titles of tv shows released in india 
data[(data['Country'] =='Nigeria') & (data['Category'] == "TV Show")]['Title']
# Out:
# 805                 Before 30
# 1238        Castle and Castle
# 1525      Crazy, Lovely, Cool
# 2156        Fifty: The Series
# 4596         Ojos in d' House
# 4616              On the Real
# 5722    Sons of the Caliphate
# 6414             The Governor
# Name: Title, dtype: object

# %%
#Top 10 directors that submited to netflix 
data['Director'].value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: count, dtype: int64

# %%
data[(data['Category'] =="Moviw") & (data["Type"] == "Comedy") | (data["Country"] == "United Kingdom")]
# Out:
#      Show_Id Category                   Title           Director  \
# 19       s20    Movie                     '89                NaN
# 58       s59  TV Show             100% Hotter                NaN
# 82       s83    Movie     2036 Origin Unknown      Hasraf Dulull
# 85       s86  TV Show                21 Again                NaN
# 93       s94    Movie       27: Gone Too Soon  Simon Napier-Bell
# ...      ...      ...                     ...                ...
# 7670   s7669  TV Show  World War II in Colour                NaN
# 7671   s7670  TV Show  World's Busiest Cities                NaN
# 7688   s7687    Movie  XV: Beyond the Tryline   Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu        James Brown
# 7740   s7739  TV Show         Young Wallander                NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %%
#to drop all the NA temporally
data1=data.dropna()
data1[data1["Cast"].str.contains("Tom Cruise")]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      Release_Date Rating Duration                        Type  \
# 3860     1-Jan-20      R  189 min  Dramas, Independent Movies
# 5071     1-Jul-19      R  134 min      Classic Movies, Dramas
#
#                                             Description       date       Date  \
# 3860  Through chance, human action, past history and... 2020-01-01 2020-01-01
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01 2019-07-01
#
#         year
# 3860  2020.0
# 5071  2019.0

# %%
#the different rating defined by netflix
data['Rating'].value_counts()
#or
#data['Rating'].nunique()
#or
#data['Rating'].unique()
# Out:
# Rating
# TV-MA       2863
# TV-14       1931
# TV-PG        806
# R            665
# PG-13        386
# TV-Y         280
# TV-Y7        271
# PG           247
# TV-G         194
# NR            84
# G             39
# TV-Y7-FV       6
# UR             5
# NC-17          3
# Name: count, dtype: int64

# %%
#how many movies got the "Tv-14"rating in canada
data[(data['Category']== 'Movie') & (data['Rating'] == 'TV-14') & (data["Country"])]
# Out:
#      Show_Id Category                     Title            Director  \
# 8         s9    Movie                       706       Shravan Kumar
# 15       s16    Movie                     1-Oct      Kunle Afolayan
# 18       s19    Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21    Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22    Movie              ​Goli Soda 2        Vijay Milton
# ...      ...      ...                       ...                 ...
# 7765   s7764    Movie                     Zenda      Avadhoot Gupte
# 7766   s7765    Movie                      Zero          Aanand Rai
# 7770   s7769    Movie  Zindagi Kitni Haseen Hay       Anjum Shahzad
# 7771   s7770    Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7785   s7784    Movie                    Zubaan         Mozez Singh
#
#                                                    Cast   Country  \
# 8     Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...     India
# ...

# %%
#maximum duration of movie\tv show
data[['Minutes' , 'Unit']]= data["Duration"].str.split(' ', expand=True)
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0    14-Aug-20  TV-MA  4 Seasons
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4     1-Jan-20  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
data['Minutes'].apply(np.int64).max()
# Out:
# 312

# %%
#all instances where "category" is movie and type is drama or category is Tv show and type is kids Tv
data[((data["Category"] =="Movie") & (data["Type"]=="Dramas"))| ((data['Category'] =='Tv Shows') & (data['Type']=="kids'TV"))]
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...
